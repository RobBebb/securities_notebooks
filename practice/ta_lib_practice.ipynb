# %%
# All Imports
import yfinance as yf
import talib as ta
import pandas as pd
import matplotlib.pyplot as plt

# %%
# Facebook Historial Data
fb = yf.Ticker("META")
df = fb.history(start="2022-01-03")

# %%
plt.style.use('fivethirtyeight')
df['MA'] = ta.SMA(df['Close'],timeperiod=5)
df[['Close','MA']].plot(figsize=(8,8))
plt.show()

# %%
plt.style.use('fivethirtyeight')
df['MA'] = ta.SMA(df['Close'],timeperiod=5)
df['EMA'] = ta.EMA(df['Close'], timeperiod = 5)
df[['Close','MA','EMA']].plot(figsize=(8,8))
plt.show()

# %%
# RSI
df['RSI'] = ta.RSI(df['Close'],14)
df['RSI'].plot(figsize=(8,8),marker='o')
df.tail(10)
# Out:
#                                  Open        High         Low       Close  \
# Date
# 2024-09-30 00:00:00-04:00  567.700012  574.679993  564.799988  572.440002
# 2024-10-01 00:00:00-04:00  577.979980  583.039978  570.099976  576.469971
# 2024-10-02 00:00:00-04:00  574.859985  576.000000  569.340027  572.809998
# 2024-10-03 00:00:00-04:00  570.150024  583.359985  568.729980  582.770020
# 2024-10-04 00:00:00-04:00  583.729980  596.849976  581.429993  595.940002
# 2024-10-07 00:00:00-04:00  598.219971  602.950012  584.039978  584.780029
# 2024-10-08 00:00:00-04:00  589.690002  593.559998  585.969971  592.890015
# 2024-10-09 00:00:00-04:00  593.989990  594.390015  581.609985  590.510010
# 2024-10-10 00:00:00-04:00  587.570007  590.229980  582.520020  583.830017
# 2024-10-11 00:00:00-04:00  584.830017  591.210022  582.710022  589.950012
#
#                              Volume  Dividends  Stock Splits          MA  \
# Date
# 2024-09-30 00:00:00-04:00  12792300        0.0           0.0  567.856006
# 2024-10-01 00:00:00-04:00  15259300        0.0           0.0  570.483997
# 2024-10-02 00:00:00-04:00   6524700        0.0           0.0  571.383997
# 2024-10-03 00:00:00-04:00  11581000        0.0           0.0  574.369995
# 2024-10-04 00:00:00-04:00  14169500        0.0           0.0  580.085999
# 2024-10-07 00:00:00-04:00  12014200        0.0           0.0  582.554004
# 2024-10-08 00:00:00-04:00   7857400        0.0           0.0  585.838013
# 2024-10-09 00:00:00-04:00   9529700        0.0           0.0  589.378015
# 2024-10-10 00:00:00-04:00   7740400        0.0           0.0  589.590015
# 2024-10-11 00:00:00-04:00   8571300        0.0           0.0  588.392017
#
#                                   EMA        RSI
# Date
# 2024-09-30 00:00:00-04:00  567.060065  74.381350
# 2024-10-01 00:00:00-04:00  570.196700  75.812715
# 2024-10-02 00:00:00-04:00  571.067799  71.884542
# 2024-10-03 00:00:00-04:00  574.968539  75.591049
# 2024-10-04 00:00:00-04:00  581.959027  79.449041
# 2024-10-07 00:00:00-04:00  582.899361  69.434115
# 2024-10-08 00:00:00-04:00  586.229579  72.178708
# 2024-10-09 00:00:00-04:00  587.656389  70.186935
# 2024-10-10 00:00:00-04:00  586.380932  64.783409
# 2024-10-11 00:00:00-04:00  587.570625  67.269587
