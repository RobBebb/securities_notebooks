# %%
import bt

# %%
# %matplotlib inline

# %%
# fetch some data
data = bt.get('spy,agg', start='2010-01-01')
print(data.head())
# Out:
# [*********************100%***********************]  1 of 1 completed
# [*********************100%***********************]  1 of 1 completed
#                   spy        agg
# Date
# 2010-01-04  86.315979  69.580704
# 2010-01-05  86.544487  69.897247
# 2010-01-06  86.605438  69.856812
# 2010-01-07  86.971008  69.775993
# 2010-01-08  87.260414  69.816452

# %%
# create the strategy
s = bt.Strategy('s1', [bt.algos.RunMonthly(),
                       bt.algos.SelectAll(),
                       bt.algos.WeighEqually(),
                       bt.algos.Rebalance()])

# %%
# create a backtest and run it
test = bt.Backtest(s, data)
res = bt.run(test)
# Out:
# 100%|██████████| 1/1 [00:00<00:00,  4.95it/s]

# %%
# first let's see an equity curve
res.plot();

# %%
# ok and what about some stats?
res.display()
# Out:
# Stat                 s1
# -------------------  ----------
# Start                2010-01-03
# End                  2024-10-04
# Risk-free rate       0.00%
#
# Total Return         224.03%
# Daily Sharpe         0.95
# Daily Sortino        1.48
# CAGR                 8.30%
# Max Drawdown         -19.87%
# Calmar Ratio         0.42
#
# MTD                  -0.57%
# 3m                   4.09%
# 6m                   8.60%
# YTD                  12.39%
# 1Y                   23.61%
# 3Y (ann.)            5.06%
# 5Y (ann.)            8.12%
# 10Y (ann.)           7.67%
# Since Incep. (ann.)  8.30%
#
# Daily Sharpe         0.95
# Daily Sortino        1.48
# Daily Mean (ann.)    8.36%
# Daily Vol (ann.)     8.76%
# Daily Skew           -0.71
# Daily Kurt           13.80
# Best Day             4.77%
# Worst Day            -6.63%
#
# Monthly Sharpe       1.04
# Monthly Sortino      1.91
# Monthly Mean (ann.)  8.46%
# Monthly Vol (ann.)   8.12%
# Monthly Skew         -0.35
# Monthly Kurt         1.06
# Best Month           7.57%
# Worst Month          -6.68%
#
# Yearly Sharpe        0.94
# Yearly Sortino       2.05
# Yearly Mean          8.37%
# Yearly Vol           8.88%
# Yearly Skew          -1.58
# Yearly Kurt          3.03
# Best Year            19.64%
# Worst Year           -15.30%
#
# Avg. Drawdown        -0.86%
# Avg. Drawdown Days   15.05
# Avg. Up Month        1.91%
# Avg. Down Month      -1.96%
# Win Year %           85.71%
# Win 12m %            90.42%

# %%
# ok and how does the return distribution look like?
res.plot_histogram()

# %%
# and just to make sure everything went along as planned, let's plot the security weights over time
res.plot_security_weights()
