# %%
import pandas as pd
from trading_formations.trading_formations import DarkCloudCover

# %%
data = pd.read_csv("test_data.csv")
data.set_index("date", inplace=True)

# %%
dark_cloud_cover = DarkCloudCover(data)
dark_cloud_cover.find_dark_cloud_covers()
dark_cloud_cover.calculate_strength()
dark_cloud_cover.calculate_resistance()
print(dark_cloud_cover.data.info())

print(dark_cloud_cover.data.head(20))

# print(engulfing.data["bullish_engulfing"].loc["2024-06-07"])

print(dark_cloud_cover.data[dark_cloud_cover.data["dark_cloud_cover"] == 1])
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 1000 entries, 2020-11-06 to 2024-10-29
# Data columns (total 21 columns):
#  #   Column                       Non-Null Count  Dtype
# ---  ------                       --------------  -----
#  0   open                         1000 non-null   float64
#  1   high                         1000 non-null   float64
#  2   low                          1000 non-null   float64
#  3   close                        1000 non-null   float64
#  4   volume                       1000 non-null   int64
#  5   real_body                    1000 non-null   float64
#  6   total_candle                 1000 non-null   float64
#  7   upper_shadow                 1000 non-null   float64
#  8   lower_shadow                 1000 non-null   float64
#  9   average_real_body            1000 non-null   float64
#  10  trend_strength_short         995 non-null    float64
#  11  trend_strength_intermediate  990 non-null    float64
# ...
